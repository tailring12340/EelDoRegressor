# %% [markdown]
# 라이브러리

# %%
import pandas as pd
import numpy as np
from keras.utils import *
from sklearn.preprocessing import *
from keras import backend as K
from keras.models import load_model
from keras.layers import LSTM, Dense
from keras.models import Sequential
import matplotlib.pyplot as plt
from keras.metrics import mean_squared_error
from sklearn.metrics import r2_score
import matplotlib.font_manager as fm
from matplotlib.dates import DateFormatter
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# 모델명(= 파일명) 설정
model_name = 'test230418-01_LSTMJaponicaTank1'

# 한글 글꼴 경로 설정
font_path = 'C:/Windows/Fonts/malgun.ttf'  # 원하는 한글 글꼴 파일 경로로 수정해주세요
font_name = fm.FontProperties(fname=font_path).get_name()
plt.rc('font', family=font_name)

# %%
# r_squared 평가 함수
def r_squared(y_true, y_pred):
    ss_res = K.sum(K.square(y_true - y_pred))
    ss_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return (1 - ss_res/(ss_tot + K.epsilon()))

# 모델 평가 함수
def grapeNEva(model, X_test_shape, y_test):
    X_pred = model.predict(X_test_shape)

    # 그래프 생성
    plt.figure(figsize=(15, 7))
    plt.plot(y_test.index, y_test, label='actual')  # x축에 년월일, y축에 값
    plt.plot(y_test.index, X_pred, color='red', label='prediction')  # x축에 년월일, y축에 시분
    plt.xlabel('날짜')
    plt.ylabel('DO')
    plt.title('시계열')
    plt.legend(['y_test','X_pred'])
    plt.show()
    
    # 평가 생성
    result = model.evaluate(X_test_shape, y_test)
    print("MSE // MAE // R-squared ", result)

# %% [markdown]
# 데이터셋 설정

# %%
#자포니카 훈련 데이터
japonica_training_food_supply_tb = pd.read_csv("E:/kimwoojae/Research/DO Regressor/dataset/japonica_training_food_supply_tb.csv")
japonica_training_sensor_val_tb = pd.read_csv("E:/kimwoojae/Research/DO Regressor/dataset/japonica_training_sensor_val_tb.csv")

#자포니카 검증 데이터
japonica_validation_food_supply_tb = pd.read_csv("E:/kimwoojae/Research/DO Regressor/dataset/japonica_validation_food_supply_tb.csv")
japonica_validation_sensor_val_tb = pd.read_csv("E:/kimwoojae/Research/DO Regressor/dataset/japonica_validation_sensor_val_tb.csv")

#자포니카 훈련 데이터 시계열 변환
japonica_training_sensor_val_tb["mea_dt"] = japonica_training_sensor_val_tb["mea_dt"].apply(str)
japonica_training_sensor_val_tb["mea_dt"] = japonica_training_sensor_val_tb["mea_dt"].str.slice(start=0, stop=16)
japonica_training_food_supply_tb['feed_dt'] = pd.to_datetime(japonica_training_food_supply_tb['feed_dt'], format='%Y%m%d%H%M', errors='raise')
japonica_training_food_supply_tb["feed_dt"] = japonica_training_food_supply_tb["feed_dt"].apply(str)
japonica_training_food_supply_tb["feed_dt"] = japonica_training_food_supply_tb["feed_dt"].str.slice(start=0, stop=16)

#자포니카 검증 데이터 시계열 변환
japonica_validation_sensor_val_tb["mea_dt"] = japonica_validation_sensor_val_tb["mea_dt"].apply(str)
japonica_validation_sensor_val_tb["mea_dt"] = japonica_validation_sensor_val_tb["mea_dt"].str.slice(start=0, stop=16)
japonica_validation_food_supply_tb['feed_dt'] = pd.to_datetime(japonica_validation_food_supply_tb['feed_dt'], format='%Y%m%d%H%M', errors='raise')
japonica_validation_food_supply_tb["feed_dt"] = japonica_validation_food_supply_tb["feed_dt"].apply(str)
japonica_validation_food_supply_tb["feed_dt"] = japonica_validation_food_supply_tb["feed_dt"].str.slice(start=0, stop=16)

# 자포니카 훈련 데이터 및 시계열 데이터 병합
japonica_training = pd.merge(left = japonica_training_sensor_val_tb, right = japonica_training_food_supply_tb, how = "left", left_on = ["farm_id","tank_id", "mea_dt"], right_on = ["farm_id","tank_id", "feed_dt"])
japonica_validation = pd.merge(left = japonica_validation_sensor_val_tb, right = japonica_validation_food_supply_tb, how = "left", left_on = ["farm_id","tank_id", "mea_dt"], right_on = ["farm_id","tank_id", "feed_dt"])

#자포니카 훈련 및 검증 데이터 시계열 변환
japonica_training['mea_dt'] = pd.to_datetime(japonica_training['mea_dt'], format='%Y-%m-%d %H:%M', errors='raise')
japonica_validation['mea_dt'] = pd.to_datetime(japonica_validation['mea_dt'], format='%Y-%m-%d %H:%M', errors='raise')

# 날짜 데이터를 인덱스로 전환
japonica_training.set_index('mea_dt', inplace=True)
japonica_validation.set_index('mea_dt', inplace=True)

# 인덱스 순으로 데이터를 정렬
japonica_training = japonica_training.sort_index()
japonica_validation = japonica_validation.sort_index()

# %%
# 사용할 features 선택
feature_origin = ['tank_id','do_mg','do_temp', 'ph', 'orp', 'co2_mg', 'air_oxy', 'light_ma', 'feed_quantity', 'water_quantity']
japonica_training_features = japonica_training[feature_origin]
japonica_validation_features = japonica_validation[feature_origin]

# nan 값 처리 (먹이를 주지 않았을 경우는 급여량이 0이니까)
japonica_training_features = japonica_training_features.fillna(0)
japonica_validation_features = japonica_validation_features.fillna(0)

# %%
# 독립 변수, 종속 변수 분리
feature_Learning = ['do_temp', 'ph', 'orp', 'co2_mg']
feature_number = len(feature_Learning)

# 자포니카 검증 데이터의 한 개 탱크
tank = 1
japonica_training_features_tank = japonica_training_features[japonica_training_features['tank_id']==tank]
japonica_validation_features_tank = japonica_validation_features[japonica_validation_features['tank_id']==tank]

japonica_training_features_X = japonica_training_features_tank[feature_Learning]
japonica_training_features_y = japonica_training_features_tank[['do_mg']]
japonica_validation_features_X = japonica_validation_features_tank[feature_Learning]
japonica_validation_features_y = japonica_validation_features_tank[['do_mg']]

# %%
# LSTM학습을 위해 데이터 reshape를 해야함. reshape를 위해 배열형으로 변환
japonica_training_features_X_reshape = np.asarray(japonica_training_features_X, dtype=np.float64)
japonica_validation_features_X_reshape = np.asarray(japonica_validation_features_X, dtype=np.float64)

# 데이터를 3항으로 reshape. (batch_size, timesteps, features)
# batch_size: 한 번에 모델에 입력되는 샘플의 개수
# timesteps: 입력되는 시퀀스 데이터의 길이(시간축)
# features: 입력되는 데이터의 특성 개수
# 말이 어려우니까 쉽게 쓰면 (얼마 만큼의 샘플을, 시간 당 몇 개씩, 항목이 몇 개인가)
# (-1 : 있는 만큼의 샘플을, 1 : 시간당 1개씩, 8 : 피처는 8개입니다.)
japonica_training_features_X_reshape = japonica_training_features_X_reshape.reshape((-1, 1, feature_number))
japonica_validation_features_X_reshape = japonica_validation_features_X_reshape.reshape((-1, 1, feature_number))

# %%
# shape확인
nCar = japonica_training_features_X_reshape.shape[0] # 데이터 개수
nVar = japonica_training_features_X_reshape.shape[2] # 변수 개수
print('nCar: %d' % nCar, 'nVar: %d' % nVar )

nCar = japonica_training_features_y.shape[0] # 데이터 개수
nVar = japonica_training_features_y.shape[1] # 변수 개수
print('nCar: %d' % nCar, 'nVar: %d' % nVar )

# shape확인
nCar = japonica_validation_features_X_reshape.shape[0] # 데이터 개수
nVar = japonica_validation_features_X_reshape.shape[2] # 변수 개수
print('nCar: %d' % nCar, 'nVar: %d' % nVar )

nCar = japonica_validation_features_y.shape[0] # 데이터 개수
nVar = japonica_validation_features_y.shape[1] # 변수 개수
print('nCar: %d' % nCar, 'nVar: %d' % nVar )
# Out:
# nCar: 222751 nVar: 4
# nCar: 222751 nVar: 1
# nCar: 222751 nVar: 4
# nCar: 222751 nVar: 1

# %% [markdown]
# LSTM 모델 학습 (학습시에만 사용, 그외에는 불필요)

# %%
# LSTM 모델 생성
model = Sequential()
# 결과값이 128개 -> 64개 -> 32개 -> 1개(회귀)
# input_shape=(timesteps, input_dim)
# timesteps : 시계열 데이터의 시간 스텝 수.
#       예를 들어, 1분 단위로 측정한 센서 데이터가 있다면 timesteps는 60.
# input_dim : 특성(feature)의 수.
model.add(LSTM(128, input_shape=(1, feature_number), return_sequences=True))
model.add(LSTM(64, return_sequences=True))
model.add(LSTM(32))
model.add(Dense(1, activation='linear'))
 
model.summary()

# mae와 r_squared 평가함수 추가.
model.compile(optimizer='adam', loss='mse', metrics=['mae', r_squared])

checkpoint = ModelCheckpoint(model_name + '_best.h5', monitor='val_loss', save_best_only=True)
early_stop = EarlyStopping(monitor='val_loss', patience=5, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1)

# ModelCheckpoint : 검증 손실이 낮아진 경우에 최적의 모델을 저장
# EarlyStopping : 검증 손실이 일정 기간동안 향상되지 않으면 학습을 조기 종료
# ReduceLROnPlateau : 검증 손실이 개선되지 않으면 학습률을 조정하는 등의 동작 수행.

hist = model.fit(japonica_training_features_X_reshape, japonica_training_features_y, epochs = 200, batch_size = 64, validation_data=(japonica_validation_features_X_reshape, japonica_validation_features_y), callbacks=[checkpoint, early_stop, reduce_lr])
model.save(model_name+'.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 128)            68096
#
#  lstm_1 (LSTM)               (None, 1, 64)             49408
#
#  lstm_2 (LSTM)               (None, 32)                12416
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 129,953
# Trainable params: 129,953
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 3481/3481 [==============================] - 30s 7ms/step - loss: 3.2583 - mae: 1.4327 - r_squared: -0.0979 - val_loss: 2.2754 - val_mae: 1.2025 - val_r_squared: -102.8149 - lr: 0.0010
# Epoch 2/200
# 3481/3481 [==============================] - 22s 6ms/step - loss: 2.2839 - mae: 1.2159 - r_squared: 0.2280 - val_loss: 2.3090 - val_mae: 1.2498 - val_r_squared: -109.9434 - lr: 0.0010
# Epoch 3/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 2.2183 - mae: 1.2020 - r_squared: 0.2493 - val_loss: 2.1439 - val_mae: 1.1909 - val_r_squared: -96.9127 - lr: 0.0010
# Epoch 4/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 2.1722 - mae: 1.1909 - r_squared: 0.2652 - val_loss: 2.1035 - val_mae: 1.1749 - val_r_squared: -96.7159 - lr: 0.0010
# Epoch 5/200
# 3481/3481 [==============================] - 23s 6ms/step - loss: 2.1299 - mae: 1.1784 - r_squared: 0.2791 - val_loss: 2.0629 - val_mae: 1.1733 - val_r_squared: -95.4674 - lr: 0.0010
# Epoch 6/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 2.0368 - mae: 1.1416 - r_squared: 0.3101 - val_loss: 2.2965 - val_mae: 1.2109 - val_r_squared: -103.1796 - lr: 0.0010
# Epoch 7/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.9433 - mae: 1.0999 - r_squared: 0.3419 - val_loss: 1.9485 - val_mae: 1.1196 - val_r_squared: -85.8986 - lr: 0.0010
# Epoch 8/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.8857 - mae: 1.0793 - r_squared: 0.3607 - val_loss: 1.7791 - val_mae: 1.0541 - val_r_squared: -77.1992 - lr: 0.0010
# Epoch 9/200
# 3481/3481 [==============================] - 19s 6ms/step - loss: 1.8189 - mae: 1.0535 - r_squared: 0.3832 - val_loss: 1.8081 - val_mae: 1.0479 - val_r_squared: -79.4789 - lr: 0.0010
# Epoch 10/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.7629 - mae: 1.0300 - r_squared: 0.4019 - val_loss: 1.9261 - val_mae: 1.0869 - val_r_squared: -85.1572 - lr: 0.0010
# Epoch 11/200
# 3476/3481 [============================>.] - ETA: 0s - loss: 1.7137 - mae: 1.0098 - r_squared: 0.4190
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.7139 - mae: 1.0099 - r_squared: 0.4188 - val_loss: 1.8065 - val_mae: 1.0317 - val_r_squared: -82.2887 - lr: 0.0010
# Epoch 12/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.5633 - mae: 0.9545 - r_squared: 0.4690 - val_loss: 1.5416 - val_mae: 0.9471 - val_r_squared: -67.2461 - lr: 1.0000e-04
# Epoch 13/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.5467 - mae: 0.9475 - r_squared: 0.4754 - val_loss: 1.5284 - val_mae: 0.9400 - val_r_squared: -66.4392 - lr: 1.0000e-04
# Epoch 14/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.5329 - mae: 0.9418 - r_squared: 0.4800 - val_loss: 1.5285 - val_mae: 0.9417 - val_r_squared: -67.6333 - lr: 1.0000e-04
# Epoch 15/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.5215 - mae: 0.9367 - r_squared: 0.4838 - val_loss: 1.5180 - val_mae: 0.9243 - val_r_squared: -66.4206 - lr: 1.0000e-04
# Epoch 16/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.5105 - mae: 0.9318 - r_squared: 0.4867 - val_loss: 1.5076 - val_mae: 0.9290 - val_r_squared: -66.0281 - lr: 1.0000e-04
# Epoch 17/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.5007 - mae: 0.9271 - r_squared: 0.4903 - val_loss: 1.4980 - val_mae: 0.9287 - val_r_squared: -65.7227 - lr: 1.0000e-04
# Epoch 18/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.4920 - mae: 0.9230 - r_squared: 0.4928 - val_loss: 1.4699 - val_mae: 0.9176 - val_r_squared: -63.8006 - lr: 1.0000e-04
# Epoch 19/200
# 3481/3481 [==============================] - 19s 6ms/step - loss: 1.4815 - mae: 0.9189 - r_squared: 0.4974 - val_loss: 1.4703 - val_mae: 0.9168 - val_r_squared: -64.2811 - lr: 1.0000e-04
# Epoch 20/200
# 3481/3481 [==============================] - 19s 6ms/step - loss: 1.4721 - mae: 0.9143 - r_squared: 0.4999 - val_loss: 1.4711 - val_mae: 0.9159 - val_r_squared: -63.3847 - lr: 1.0000e-04
# Epoch 21/200
# 3472/3481 [============================>.] - ETA: 0s - loss: 1.4633 - mae: 0.9110 - r_squared: 0.5028
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 3481/3481 [==============================] - 19s 5ms/step - loss: 1.4633 - mae: 0.9110 - r_squared: 0.5029 - val_loss: 1.4936 - val_mae: 0.9251 - val_r_squared: -64.4790 - lr: 1.0000e-04
# Epoch 22/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.4408 - mae: 0.9025 - r_squared: 0.5106 - val_loss: 1.4401 - val_mae: 0.9005 - val_r_squared: -62.0266 - lr: 1.0000e-05
# Epoch 23/200
# 3481/3481 [==============================] - 19s 5ms/step - loss: 1.4387 - mae: 0.9010 - r_squared: 0.5115 - val_loss: 1.4389 - val_mae: 0.9010 - val_r_squared: -62.5684 - lr: 1.0000e-05
# Epoch 24/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.4374 - mae: 0.9005 - r_squared: 0.5117 - val_loss: 1.4359 - val_mae: 0.8979 - val_r_squared: -61.9438 - lr: 1.0000e-05
# Epoch 25/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.4366 - mae: 0.9001 - r_squared: 0.5118 - val_loss: 1.4346 - val_mae: 0.8988 - val_r_squared: -62.0523 - lr: 1.0000e-05
# Epoch 26/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.4354 - mae: 0.8995 - r_squared: 0.5123 - val_loss: 1.4339 - val_mae: 0.8999 - val_r_squared: -62.0362 - lr: 1.0000e-05
# Epoch 27/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.4340 - mae: 0.8991 - r_squared: 0.5126 - val_loss: 1.4327 - val_mae: 0.8973 - val_r_squared: -62.0282 - lr: 1.0000e-05
# Epoch 28/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.4330 - mae: 0.8985 - r_squared: 0.5129 - val_loss: 1.4314 - val_mae: 0.9003 - val_r_squared: -62.0858 - lr: 1.0000e-05
# Epoch 29/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.4321 - mae: 0.8982 - r_squared: 0.5136 - val_loss: 1.4349 - val_mae: 0.8959 - val_r_squared: -61.7780 - lr: 1.0000e-05
# Epoch 30/200
# 3481/3481 [==============================] - 22s 6ms/step - loss: 1.4309 - mae: 0.8977 - r_squared: 0.5143 - val_loss: 1.4290 - val_mae: 0.8960 - val_r_squared: -61.6402 - lr: 1.0000e-05
# Epoch 31/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.4296 - mae: 0.8972 - r_squared: 0.5145 - val_loss: 1.4273 - val_mae: 0.8960 - val_r_squared: -61.7979 - lr: 1.0000e-05
# Epoch 32/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.4287 - mae: 0.8966 - r_squared: 0.5145 - val_loss: 1.4262 - val_mae: 0.8974 - val_r_squared: -61.7506 - lr: 1.0000e-05
# Epoch 33/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.4273 - mae: 0.8964 - r_squared: 0.5153 - val_loss: 1.4260 - val_mae: 0.8930 - val_r_squared: -61.6505 - lr: 1.0000e-05
# Epoch 34/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.4264 - mae: 0.8959 - r_squared: 0.5153 - val_loss: 1.4243 - val_mae: 0.8928 - val_r_squared: -61.6424 - lr: 1.0000e-05
# Epoch 35/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.4253 - mae: 0.8952 - r_squared: 0.5158 - val_loss: 1.4241 - val_mae: 0.8932 - val_r_squared: -61.5217 - lr: 1.0000e-05
# Epoch 36/200
# 3481/3481 [==============================] - 19s 6ms/step - loss: 1.4244 - mae: 0.8949 - r_squared: 0.5159 - val_loss: 1.4232 - val_mae: 0.8967 - val_r_squared: -61.7801 - lr: 1.0000e-05
# Epoch 37/200
# 3481/3481 [==============================] - 19s 6ms/step - loss: 1.4230 - mae: 0.8944 - r_squared: 0.5169 - val_loss: 1.4232 - val_mae: 0.8946 - val_r_squared: -61.4553 - lr: 1.0000e-05
# Epoch 38/200
# 3481/3481 [==============================] - 19s 6ms/step - loss: 1.4215 - mae: 0.8938 - r_squared: 0.5173 - val_loss: 1.4198 - val_mae: 0.8938 - val_r_squared: -61.2954 - lr: 1.0000e-05
# Epoch 39/200
# 3481/3481 [==============================] - 19s 5ms/step - loss: 1.4210 - mae: 0.8933 - r_squared: 0.5170 - val_loss: 1.4218 - val_mae: 0.8956 - val_r_squared: -61.7680 - lr: 1.0000e-05
# Epoch 40/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.4200 - mae: 0.8932 - r_squared: 0.5168 - val_loss: 1.4190 - val_mae: 0.8931 - val_r_squared: -61.2755 - lr: 1.0000e-05
# Epoch 41/200
# 3481/3481 [==============================] - 22s 6ms/step - loss: 1.4187 - mae: 0.8927 - r_squared: 0.5178 - val_loss: 1.4177 - val_mae: 0.8920 - val_r_squared: -61.4680 - lr: 1.0000e-05
# Epoch 42/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.4173 - mae: 0.8921 - r_squared: 0.5180 - val_loss: 1.4156 - val_mae: 0.8910 - val_r_squared: -61.3176 - lr: 1.0000e-05
# Epoch 43/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.4166 - mae: 0.8916 - r_squared: 0.5187 - val_loss: 1.4147 - val_mae: 0.8908 - val_r_squared: -61.1812 - lr: 1.0000e-05
# Epoch 44/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.4154 - mae: 0.8911 - r_squared: 0.5186 - val_loss: 1.4138 - val_mae: 0.8915 - val_r_squared: -61.1778 - lr: 1.0000e-05
# Epoch 45/200
# 3481/3481 [==============================] - 22s 6ms/step - loss: 1.4141 - mae: 0.8908 - r_squared: 0.5204 - val_loss: 1.4166 - val_mae: 0.8880 - val_r_squared: -61.1020 - lr: 1.0000e-05
# Epoch 46/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.4130 - mae: 0.8903 - r_squared: 0.5194 - val_loss: 1.4127 - val_mae: 0.8862 - val_r_squared: -61.3371 - lr: 1.0000e-05
# Epoch 47/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.4120 - mae: 0.8896 - r_squared: 0.5199 - val_loss: 1.4169 - val_mae: 0.8890 - val_r_squared: -61.4533 - lr: 1.0000e-05
# Epoch 48/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.4110 - mae: 0.8893 - r_squared: 0.5208 - val_loss: 1.4129 - val_mae: 0.8904 - val_r_squared: -61.3927 - lr: 1.0000e-05
# Epoch 49/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.4097 - mae: 0.8889 - r_squared: 0.5211 - val_loss: 1.4089 - val_mae: 0.8898 - val_r_squared: -61.0975 - lr: 1.0000e-05
# Epoch 50/200
# 3481/3481 [==============================] - 19s 6ms/step - loss: 1.4089 - mae: 0.8882 - r_squared: 0.5212 - val_loss: 1.4096 - val_mae: 0.8933 - val_r_squared: -61.3703 - lr: 1.0000e-05
# Epoch 51/200
# 3481/3481 [==============================] - 19s 6ms/step - loss: 1.4078 - mae: 0.8882 - r_squared: 0.5221 - val_loss: 1.4076 - val_mae: 0.8902 - val_r_squared: -60.9895 - lr: 1.0000e-05
# Epoch 52/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.4063 - mae: 0.8875 - r_squared: 0.5220 - val_loss: 1.4039 - val_mae: 0.8869 - val_r_squared: -60.6176 - lr: 1.0000e-05
# Epoch 53/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.4054 - mae: 0.8873 - r_squared: 0.5225 - val_loss: 1.4038 - val_mae: 0.8862 - val_r_squared: -60.9770 - lr: 1.0000e-05
# Epoch 54/200
# 3481/3481 [==============================] - 19s 5ms/step - loss: 1.4041 - mae: 0.8867 - r_squared: 0.5229 - val_loss: 1.4016 - val_mae: 0.8857 - val_r_squared: -60.7687 - lr: 1.0000e-05
# Epoch 55/200
# 3481/3481 [==============================] - 19s 5ms/step - loss: 1.4032 - mae: 0.8862 - r_squared: 0.5230 - val_loss: 1.4008 - val_mae: 0.8850 - val_r_squared: -60.5300 - lr: 1.0000e-05
# Epoch 56/200
# 3481/3481 [==============================] - 19s 6ms/step - loss: 1.4017 - mae: 0.8859 - r_squared: 0.5238 - val_loss: 1.4004 - val_mae: 0.8839 - val_r_squared: -60.5299 - lr: 1.0000e-05
# Epoch 57/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.4006 - mae: 0.8852 - r_squared: 0.5231 - val_loss: 1.4005 - val_mae: 0.8853 - val_r_squared: -60.5172 - lr: 1.0000e-05
# Epoch 58/200
# 3481/3481 [==============================] - 19s 6ms/step - loss: 1.3998 - mae: 0.8851 - r_squared: 0.5243 - val_loss: 1.3971 - val_mae: 0.8826 - val_r_squared: -60.6489 - lr: 1.0000e-05
# Epoch 59/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3986 - mae: 0.8846 - r_squared: 0.5246 - val_loss: 1.3969 - val_mae: 0.8814 - val_r_squared: -60.3812 - lr: 1.0000e-05
# Epoch 60/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3970 - mae: 0.8838 - r_squared: 0.5243 - val_loss: 1.3942 - val_mae: 0.8827 - val_r_squared: -60.4608 - lr: 1.0000e-05
# Epoch 61/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3963 - mae: 0.8835 - r_squared: 0.5257 - val_loss: 1.3943 - val_mae: 0.8830 - val_r_squared: -60.3124 - lr: 1.0000e-05
# Epoch 62/200
# 3481/3481 [==============================] - 19s 6ms/step - loss: 1.3946 - mae: 0.8829 - r_squared: 0.5261 - val_loss: 1.3919 - val_mae: 0.8824 - val_r_squared: -60.2931 - lr: 1.0000e-05
# Epoch 63/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3932 - mae: 0.8825 - r_squared: 0.5265 - val_loss: 1.3923 - val_mae: 0.8819 - val_r_squared: -60.4141 - lr: 1.0000e-05
# Epoch 64/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3925 - mae: 0.8821 - r_squared: 0.5268 - val_loss: 1.3902 - val_mae: 0.8806 - val_r_squared: -60.4239 - lr: 1.0000e-05
# Epoch 65/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3914 - mae: 0.8816 - r_squared: 0.5273 - val_loss: 1.3892 - val_mae: 0.8824 - val_r_squared: -60.5139 - lr: 1.0000e-05
# Epoch 66/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3896 - mae: 0.8813 - r_squared: 0.5280 - val_loss: 1.3963 - val_mae: 0.8809 - val_r_squared: -60.9232 - lr: 1.0000e-05
# Epoch 67/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3888 - mae: 0.8805 - r_squared: 0.5285 - val_loss: 1.3901 - val_mae: 0.8819 - val_r_squared: -60.1889 - lr: 1.0000e-05
# Epoch 68/200
# 3481/3481 [==============================] - 19s 6ms/step - loss: 1.3872 - mae: 0.8803 - r_squared: 0.5283 - val_loss: 1.3889 - val_mae: 0.8779 - val_r_squared: -60.0644 - lr: 1.0000e-05
# Epoch 69/200
# 3481/3481 [==============================] - 19s 6ms/step - loss: 1.3864 - mae: 0.8798 - r_squared: 0.5291 - val_loss: 1.3857 - val_mae: 0.8809 - val_r_squared: -60.4256 - lr: 1.0000e-05
# Epoch 70/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3846 - mae: 0.8792 - r_squared: 0.5292 - val_loss: 1.3824 - val_mae: 0.8792 - val_r_squared: -60.1332 - lr: 1.0000e-05
# Epoch 71/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3834 - mae: 0.8786 - r_squared: 0.5297 - val_loss: 1.3834 - val_mae: 0.8820 - val_r_squared: -60.0463 - lr: 1.0000e-05
# Epoch 72/200
# 3481/3481 [==============================] - 22s 6ms/step - loss: 1.3822 - mae: 0.8783 - r_squared: 0.5304 - val_loss: 1.3827 - val_mae: 0.8825 - val_r_squared: -60.3133 - lr: 1.0000e-05
# Epoch 73/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3806 - mae: 0.8779 - r_squared: 0.5311 - val_loss: 1.3790 - val_mae: 0.8745 - val_r_squared: -59.7413 - lr: 1.0000e-05
# Epoch 74/200
# 3481/3481 [==============================] - 22s 6ms/step - loss: 1.3798 - mae: 0.8771 - r_squared: 0.5312 - val_loss: 1.3763 - val_mae: 0.8764 - val_r_squared: -59.8155 - lr: 1.0000e-05
# Epoch 75/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3781 - mae: 0.8768 - r_squared: 0.5317 - val_loss: 1.3779 - val_mae: 0.8741 - val_r_squared: -59.6507 - lr: 1.0000e-05
# Epoch 76/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3766 - mae: 0.8762 - r_squared: 0.5322 - val_loss: 1.3741 - val_mae: 0.8749 - val_r_squared: -59.7401 - lr: 1.0000e-05
# Epoch 77/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3754 - mae: 0.8756 - r_squared: 0.5322 - val_loss: 1.3732 - val_mae: 0.8747 - val_r_squared: -59.6387 - lr: 1.0000e-05
# Epoch 78/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3741 - mae: 0.8752 - r_squared: 0.5328 - val_loss: 1.3738 - val_mae: 0.8749 - val_r_squared: -59.9427 - lr: 1.0000e-05
# Epoch 79/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3729 - mae: 0.8748 - r_squared: 0.5330 - val_loss: 1.3697 - val_mae: 0.8738 - val_r_squared: -59.6293 - lr: 1.0000e-05
# Epoch 80/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3713 - mae: 0.8739 - r_squared: 0.5340 - val_loss: 1.3728 - val_mae: 0.8781 - val_r_squared: -59.6977 - lr: 1.0000e-05
# Epoch 81/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3698 - mae: 0.8738 - r_squared: 0.5338 - val_loss: 1.3681 - val_mae: 0.8714 - val_r_squared: -59.6445 - lr: 1.0000e-05
# Epoch 82/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3686 - mae: 0.8732 - r_squared: 0.5354 - val_loss: 1.3685 - val_mae: 0.8720 - val_r_squared: -59.4451 - lr: 1.0000e-05
# Epoch 83/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3669 - mae: 0.8723 - r_squared: 0.5362 - val_loss: 1.3682 - val_mae: 0.8685 - val_r_squared: -59.6979 - lr: 1.0000e-05
# Epoch 84/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3655 - mae: 0.8718 - r_squared: 0.5359 - val_loss: 1.3626 - val_mae: 0.8705 - val_r_squared: -59.3018 - lr: 1.0000e-05
# Epoch 85/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3641 - mae: 0.8716 - r_squared: 0.5362 - val_loss: 1.3630 - val_mae: 0.8725 - val_r_squared: -59.3816 - lr: 1.0000e-05
# Epoch 86/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3628 - mae: 0.8708 - r_squared: 0.5370 - val_loss: 1.3598 - val_mae: 0.8699 - val_r_squared: -59.3403 - lr: 1.0000e-05
# Epoch 87/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3615 - mae: 0.8702 - r_squared: 0.5367 - val_loss: 1.3592 - val_mae: 0.8719 - val_r_squared: -59.2699 - lr: 1.0000e-05
# Epoch 88/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3600 - mae: 0.8696 - r_squared: 0.5376 - val_loss: 1.3578 - val_mae: 0.8716 - val_r_squared: -59.3251 - lr: 1.0000e-05
# Epoch 89/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3589 - mae: 0.8694 - r_squared: 0.5385 - val_loss: 1.3552 - val_mae: 0.8693 - val_r_squared: -59.0660 - lr: 1.0000e-05
# Epoch 90/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3574 - mae: 0.8689 - r_squared: 0.5382 - val_loss: 1.3570 - val_mae: 0.8661 - val_r_squared: -58.9824 - lr: 1.0000e-05
# Epoch 91/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3557 - mae: 0.8677 - r_squared: 0.5398 - val_loss: 1.3525 - val_mae: 0.8692 - val_r_squared: -59.0017 - lr: 1.0000e-05
# Epoch 92/200
# 3481/3481 [==============================] - 19s 6ms/step - loss: 1.3543 - mae: 0.8675 - r_squared: 0.5400 - val_loss: 1.3581 - val_mae: 0.8680 - val_r_squared: -59.6239 - lr: 1.0000e-05
# Epoch 93/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3532 - mae: 0.8668 - r_squared: 0.5403 - val_loss: 1.3525 - val_mae: 0.8693 - val_r_squared: -59.3431 - lr: 1.0000e-05
# Epoch 94/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3516 - mae: 0.8666 - r_squared: 0.5406 - val_loss: 1.3479 - val_mae: 0.8649 - val_r_squared: -58.8108 - lr: 1.0000e-05
# Epoch 95/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3502 - mae: 0.8658 - r_squared: 0.5410 - val_loss: 1.3483 - val_mae: 0.8635 - val_r_squared: -58.8556 - lr: 1.0000e-05
# Epoch 96/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3489 - mae: 0.8653 - r_squared: 0.5417 - val_loss: 1.3454 - val_mae: 0.8633 - val_r_squared: -58.7520 - lr: 1.0000e-05
# Epoch 97/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3471 - mae: 0.8647 - r_squared: 0.5423 - val_loss: 1.3484 - val_mae: 0.8603 - val_r_squared: -58.8567 - lr: 1.0000e-05
# Epoch 98/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3459 - mae: 0.8640 - r_squared: 0.5432 - val_loss: 1.3431 - val_mae: 0.8624 - val_r_squared: -58.7182 - lr: 1.0000e-05
# Epoch 99/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3446 - mae: 0.8636 - r_squared: 0.5430 - val_loss: 1.3423 - val_mae: 0.8638 - val_r_squared: -58.7072 - lr: 1.0000e-05
# Epoch 100/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3428 - mae: 0.8628 - r_squared: 0.5436 - val_loss: 1.3415 - val_mae: 0.8607 - val_r_squared: -58.5961 - lr: 1.0000e-05
# Epoch 101/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3415 - mae: 0.8622 - r_squared: 0.5435 - val_loss: 1.3385 - val_mae: 0.8617 - val_r_squared: -58.5869 - lr: 1.0000e-05
# Epoch 102/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3403 - mae: 0.8618 - r_squared: 0.5449 - val_loss: 1.3366 - val_mae: 0.8599 - val_r_squared: -58.4772 - lr: 1.0000e-05
# Epoch 103/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3386 - mae: 0.8610 - r_squared: 0.5454 - val_loss: 1.3390 - val_mae: 0.8567 - val_r_squared: -58.3651 - lr: 1.0000e-05
# Epoch 104/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3367 - mae: 0.8602 - r_squared: 0.5461 - val_loss: 1.3338 - val_mae: 0.8604 - val_r_squared: -58.2139 - lr: 1.0000e-05
# Epoch 105/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3353 - mae: 0.8596 - r_squared: 0.5462 - val_loss: 1.3359 - val_mae: 0.8586 - val_r_squared: -58.4650 - lr: 1.0000e-05
# Epoch 106/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3340 - mae: 0.8590 - r_squared: 0.5466 - val_loss: 1.3315 - val_mae: 0.8589 - val_r_squared: -58.4504 - lr: 1.0000e-05
# Epoch 107/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3326 - mae: 0.8586 - r_squared: 0.5474 - val_loss: 1.3304 - val_mae: 0.8572 - val_r_squared: -58.1391 - lr: 1.0000e-05
# Epoch 108/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3315 - mae: 0.8580 - r_squared: 0.5476 - val_loss: 1.3296 - val_mae: 0.8595 - val_r_squared: -58.0852 - lr: 1.0000e-05
# Epoch 109/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3295 - mae: 0.8574 - r_squared: 0.5478 - val_loss: 1.3347 - val_mae: 0.8607 - val_r_squared: -58.1851 - lr: 1.0000e-05
# Epoch 110/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3284 - mae: 0.8569 - r_squared: 0.5479 - val_loss: 1.3325 - val_mae: 0.8596 - val_r_squared: -58.7039 - lr: 1.0000e-05
# Epoch 111/200
# 3476/3481 [============================>.] - ETA: 0s - loss: 1.3272 - mae: 0.8559 - r_squared: 0.5495
# Epoch 111: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3270 - mae: 0.8559 - r_squared: 0.5495 - val_loss: 1.3299 - val_mae: 0.8616 - val_r_squared: -58.3795 - lr: 1.0000e-05
# Epoch 112/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3229 - mae: 0.8552 - r_squared: 0.5505 - val_loss: 1.3222 - val_mae: 0.8541 - val_r_squared: -57.8831 - lr: 1.0000e-06
# Epoch 113/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3225 - mae: 0.8545 - r_squared: 0.5508 - val_loss: 1.3220 - val_mae: 0.8539 - val_r_squared: -57.8573 - lr: 1.0000e-06
# Epoch 114/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3223 - mae: 0.8544 - r_squared: 0.5508 - val_loss: 1.3226 - val_mae: 0.8555 - val_r_squared: -57.9192 - lr: 1.0000e-06
# Epoch 115/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3222 - mae: 0.8542 - r_squared: 0.5508 - val_loss: 1.3218 - val_mae: 0.8549 - val_r_squared: -57.8920 - lr: 1.0000e-06
# Epoch 116/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3220 - mae: 0.8543 - r_squared: 0.5505 - val_loss: 1.3219 - val_mae: 0.8535 - val_r_squared: -57.8621 - lr: 1.0000e-06
# Epoch 117/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3219 - mae: 0.8542 - r_squared: 0.5512 - val_loss: 1.3217 - val_mae: 0.8547 - val_r_squared: -57.8463 - lr: 1.0000e-06
# Epoch 118/200
# 3481/3481 [==============================] - 22s 6ms/step - loss: 1.3216 - mae: 0.8542 - r_squared: 0.5501 - val_loss: 1.3218 - val_mae: 0.8528 - val_r_squared: -57.8296 - lr: 1.0000e-06
# Epoch 119/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3215 - mae: 0.8538 - r_squared: 0.5514 - val_loss: 1.3211 - val_mae: 0.8540 - val_r_squared: -57.8530 - lr: 1.0000e-06
# Epoch 120/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3214 - mae: 0.8541 - r_squared: 0.5507 - val_loss: 1.3209 - val_mae: 0.8538 - val_r_squared: -57.9143 - lr: 1.0000e-06
# Epoch 121/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3212 - mae: 0.8537 - r_squared: 0.5514 - val_loss: 1.3208 - val_mae: 0.8537 - val_r_squared: -57.8189 - lr: 1.0000e-06
# Epoch 122/200
# 3481/3481 [==============================] - 24s 7ms/step - loss: 1.3210 - mae: 0.8538 - r_squared: 0.5516 - val_loss: 1.3210 - val_mae: 0.8530 - val_r_squared: -57.7422 - lr: 1.0000e-06
# Epoch 123/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3209 - mae: 0.8535 - r_squared: 0.5515 - val_loss: 1.3207 - val_mae: 0.8545 - val_r_squared: -57.9281 - lr: 1.0000e-06
# Epoch 124/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3206 - mae: 0.8536 - r_squared: 0.5514 - val_loss: 1.3204 - val_mae: 0.8541 - val_r_squared: -57.9049 - lr: 1.0000e-06
# Epoch 125/200
# 3481/3481 [==============================] - 23s 7ms/step - loss: 1.3206 - mae: 0.8536 - r_squared: 0.5513 - val_loss: 1.3203 - val_mae: 0.8534 - val_r_squared: -57.8663 - lr: 1.0000e-06
# Epoch 126/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3204 - mae: 0.8535 - r_squared: 0.5511 - val_loss: 1.3200 - val_mae: 0.8539 - val_r_squared: -57.8593 - lr: 1.0000e-06
# Epoch 127/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3202 - mae: 0.8536 - r_squared: 0.5515 - val_loss: 1.3200 - val_mae: 0.8530 - val_r_squared: -57.8054 - lr: 1.0000e-06
# Epoch 128/200
# 3481/3481 [==============================] - 23s 6ms/step - loss: 1.3201 - mae: 0.8532 - r_squared: 0.5518 - val_loss: 1.3198 - val_mae: 0.8531 - val_r_squared: -57.7494 - lr: 1.0000e-06
# Epoch 129/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3199 - mae: 0.8533 - r_squared: 0.5513 - val_loss: 1.3197 - val_mae: 0.8532 - val_r_squared: -57.7356 - lr: 1.0000e-06
# Epoch 130/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3198 - mae: 0.8532 - r_squared: 0.5511 - val_loss: 1.3195 - val_mae: 0.8532 - val_r_squared: -57.7394 - lr: 1.0000e-06
# Epoch 131/200
# 3481/3481 [==============================] - 22s 6ms/step - loss: 1.3196 - mae: 0.8533 - r_squared: 0.5516 - val_loss: 1.3193 - val_mae: 0.8522 - val_r_squared: -57.7711 - lr: 1.0000e-06
# Epoch 132/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3195 - mae: 0.8531 - r_squared: 0.5516 - val_loss: 1.3191 - val_mae: 0.8521 - val_r_squared: -57.7442 - lr: 1.0000e-06
# Epoch 133/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3193 - mae: 0.8531 - r_squared: 0.5515 - val_loss: 1.3189 - val_mae: 0.8523 - val_r_squared: -57.7646 - lr: 1.0000e-06
# Epoch 134/200
# 3481/3481 [==============================] - 23s 7ms/step - loss: 1.3192 - mae: 0.8529 - r_squared: 0.5521 - val_loss: 1.3190 - val_mae: 0.8537 - val_r_squared: -57.8108 - lr: 1.0000e-06
# Epoch 135/200
# 3481/3481 [==============================] - 22s 6ms/step - loss: 1.3190 - mae: 0.8529 - r_squared: 0.5520 - val_loss: 1.3187 - val_mae: 0.8526 - val_r_squared: -57.7697 - lr: 1.0000e-06
# Epoch 136/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3189 - mae: 0.8529 - r_squared: 0.5513 - val_loss: 1.3184 - val_mae: 0.8524 - val_r_squared: -57.7349 - lr: 1.0000e-06
# Epoch 137/200
# 3481/3481 [==============================] - 22s 6ms/step - loss: 1.3187 - mae: 0.8527 - r_squared: 0.5510 - val_loss: 1.3182 - val_mae: 0.8529 - val_r_squared: -57.7722 - lr: 1.0000e-06
# Epoch 138/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3186 - mae: 0.8527 - r_squared: 0.5523 - val_loss: 1.3182 - val_mae: 0.8527 - val_r_squared: -57.7399 - lr: 1.0000e-06
# Epoch 139/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3183 - mae: 0.8525 - r_squared: 0.5522 - val_loss: 1.3194 - val_mae: 0.8546 - val_r_squared: -57.8335 - lr: 1.0000e-06
# Epoch 140/200
# 3470/3481 [============================>.] - ETA: 0s - loss: 1.3186 - mae: 0.8529 - r_squared: 0.5524
# Epoch 140: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3182 - mae: 0.8527 - r_squared: 0.5526 - val_loss: 1.3182 - val_mae: 0.8528 - val_r_squared: -57.7193 - lr: 1.0000e-06
# Epoch 141/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3179 - mae: 0.8523 - r_squared: 0.5528 - val_loss: 1.3177 - val_mae: 0.8524 - val_r_squared: -57.7326 - lr: 1.0000e-07
# Epoch 142/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3178 - mae: 0.8523 - r_squared: 0.5520 - val_loss: 1.3177 - val_mae: 0.8524 - val_r_squared: -57.7482 - lr: 1.0000e-07
# Epoch 143/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3178 - mae: 0.8524 - r_squared: 0.5522 - val_loss: 1.3177 - val_mae: 0.8524 - val_r_squared: -57.7396 - lr: 1.0000e-07
# Epoch 144/200
# 3479/3481 [============================>.] - ETA: 0s - loss: 1.3177 - mae: 0.8525 - r_squared: 0.5520
# Epoch 144: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3177 - mae: 0.8524 - r_squared: 0.5521 - val_loss: 1.3177 - val_mae: 0.8523 - val_r_squared: -57.7252 - lr: 1.0000e-07
# Epoch 145/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3177 - mae: 0.8523 - r_squared: 0.5523 - val_loss: 1.3177 - val_mae: 0.8523 - val_r_squared: -57.7272 - lr: 1.0000e-08
# Epoch 146/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3177 - mae: 0.8523 - r_squared: 0.5522 - val_loss: 1.3177 - val_mae: 0.8523 - val_r_squared: -57.7290 - lr: 1.0000e-08
# Epoch 147/200
# 3473/3481 [============================>.] - ETA: 0s - loss: 1.3176 - mae: 0.8522 - r_squared: 0.5523
# Epoch 147: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3177 - mae: 0.8523 - r_squared: 0.5523 - val_loss: 1.3177 - val_mae: 0.8523 - val_r_squared: -57.7304 - lr: 1.0000e-08
# Epoch 148/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3177 - mae: 0.8523 - r_squared: 0.5519 - val_loss: 1.3177 - val_mae: 0.8523 - val_r_squared: -57.7304 - lr: 1.0000e-09
# Epoch 149/200
# 3481/3481 [==============================] - 21s 6ms/step - loss: 1.3177 - mae: 0.8523 - r_squared: 0.5524 - val_loss: 1.3177 - val_mae: 0.8523 - val_r_squared: -57.7303 - lr: 1.0000e-09
# Epoch 150/200
# 3471/3481 [============================>.] - ETA: 0s - loss: 1.3180 - mae: 0.8524 - r_squared: 0.5520
# Epoch 150: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
# 3481/3481 [==============================] - 22s 6ms/step - loss: 1.3177 - mae: 0.8523 - r_squared: 0.5522 - val_loss: 1.3177 - val_mae: 0.8523 - val_r_squared: -57.7304 - lr: 1.0000e-09
# Epoch 151/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3177 - mae: 0.8523 - r_squared: 0.5523 - val_loss: 1.3177 - val_mae: 0.8523 - val_r_squared: -57.7304 - lr: 1.0000e-10
# Epoch 152/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3177 - mae: 0.8523 - r_squared: 0.5529 - val_loss: 1.3177 - val_mae: 0.8523 - val_r_squared: -57.7304 - lr: 1.0000e-10
# Epoch 153/200
# 3470/3481 [============================>.] - ETA: 0s - loss: 1.3172 - mae: 0.8522 - r_squared: 0.5529
# Epoch 153: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-11.
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3177 - mae: 0.8523 - r_squared: 0.5528 - val_loss: 1.3177 - val_mae: 0.8523 - val_r_squared: -57.7304 - lr: 1.0000e-10
# Epoch 154/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3177 - mae: 0.8523 - r_squared: 0.5518 - val_loss: 1.3177 - val_mae: 0.8523 - val_r_squared: -57.7304 - lr: 1.0000e-11
# Epoch 155/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3177 - mae: 0.8523 - r_squared: 0.5525 - val_loss: 1.3177 - val_mae: 0.8523 - val_r_squared: -57.7304 - lr: 1.0000e-11
# Epoch 156/200
# 3479/3481 [============================>.] - ETA: 0s - loss: 1.3178 - mae: 0.8523 - r_squared: 0.5517
# Epoch 156: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-12.
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3177 - mae: 0.8523 - r_squared: 0.5518 - val_loss: 1.3177 - val_mae: 0.8523 - val_r_squared: -57.7304 - lr: 1.0000e-11
# Epoch 157/200
# 3481/3481 [==============================] - 20s 6ms/step - loss: 1.3177 - mae: 0.8523 - r_squared: 0.5527 - val_loss: 1.3177 - val_mae: 0.8523 - val_r_squared: -57.7304 - lr: 1.0000e-12
# Epoch 157: early stopping

# %% [markdown]
# 모델 평가

# %% [markdown]
# 모델 평가

# %%
# r_squared가 따로 만들어서 추가해준 함수기 때문에 불러올 때도 추가해서 불러야한다.
model = load_model(model_name+'.h5', custom_objects={'r_squared': r_squared})

# %%
# 가중치를 통해 변수 중요도 획득
weights = model.layers[0].get_weights()[0]
print(weights)


# 변수 중요도 시각화
fig, ax = plt.subplots(figsize=(8, 4))
ax.bar(range(feature_number), weights[:, 0])
ax.set_xticks(range(feature_number))
ax.set_xticklabels(feature_Learning)
ax.set_ylabel('Weight')
ax.set_title('Variable Importance')
plt.show()
# Out:
# [[ 0.2591185  -0.09420498 -0.09965753 ...  0.05933628  0.07678853
#   -0.03967583]
#  [ 1.07437     0.61000204 -0.04849403 ...  0.12672818  0.117481
#   -0.00140631]
#  [-0.06481378 -0.0062711   0.06340588 ... -0.15538119  0.10263035
#   -0.03376464]
#  [ 0.11540768  0.08960629  0.20146154 ... -0.12918124  0.01716586
#    0.26269192]]

# %%
grapeNEva(model, japonica_validation_features_X_reshape, japonica_validation_features_y)
# Out:
# 6961/6961 [==============================] - 14s 2ms/step
# 6961/6961 [==============================] - 16s 2ms/step - loss: 1.3177 - mae: 0.8523 - r_squared: -1892.6483
# MSE // MAE // R-squared  [1.317663311958313, 0.8523079752922058, -1892.6483154296875]

# %%
# 자포니카 검증 데이터의 한 개 탱크
tank = 1
japonica_validation_features_tank = japonica_validation_features[japonica_validation_features['tank_id']==tank]

# 하루 동안의 데이터 추출
one_day_data = japonica_validation_features_tank.loc['2021-07-16 00:00:00':'2021-07-16 23:59:59']
oneday_X_test = one_day_data[feature_Learning]
oneday_y_test = one_day_data[['do_mg']]

oneday_X_test_reshape = np.asarray(oneday_X_test, dtype=np.float64)
oneday_X_test_reshape = oneday_X_test_reshape.reshape((-1, 1, feature_number))

# shape확인
nCar = oneday_X_test_reshape.shape[0] # 데이터 개수
nVar = oneday_X_test_reshape.shape[2] # 변수 개수
print('nCar: %d' % nCar, 'nVar: %d' % nVar )

nCar = oneday_y_test.shape[0] # 데이터 개수
nVar = oneday_y_test.shape[1] # 변수 개수
print('nCar: %d' % nCar, 'nVar: %d' % nVar )
# Out:
# nCar: 1440 nVar: 4
# nCar: 1440 nVar: 1

# %%
grapeNEva(model, oneday_X_test_reshape, oneday_y_test)
# Out:
# 45/45 [==============================] - 0s 2ms/step
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1571 - mae: 0.2980 - r_squared: -12.5771
# MSE // MAE // R-squared  [0.15710021555423737, 0.2979680299758911, -12.577133178710938]

# %%
# 자포니카 검증 데이터의 한 개 탱크
tank = 1
japonica_validation_features_tank = japonica_validation_features[japonica_validation_features['tank_id']==tank]

# 하루 동안의 데이터 추출
one_day_data = japonica_validation_features_tank.loc['2021-08-28 00:00:00':'2021-08-28 23:59:59']
oneday_X_test = one_day_data[feature_Learning]
oneday_y_test = one_day_data[['do_mg']]

oneday_X_test_reshape = np.asarray(oneday_X_test, dtype=np.float64)
oneday_X_test_reshape = oneday_X_test_reshape.reshape((-1, 1, feature_number))

# shape확인
nCar = oneday_X_test_reshape.shape[0] # 데이터 개수
nVar = oneday_X_test_reshape.shape[2] # 변수 개수
print('nCar: %d' % nCar, 'nVar: %d' % nVar )

nCar = oneday_y_test.shape[0] # 데이터 개수
nVar = oneday_y_test.shape[1] # 변수 개수
print('nCar: %d' % nCar, 'nVar: %d' % nVar )
# Out:
# nCar: 1440 nVar: 4
# nCar: 1440 nVar: 1

# %%
grapeNEva(model, oneday_X_test_reshape, oneday_y_test)
# Out:
# 45/45 [==============================] - 0s 2ms/step
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2004 - mae: 0.3449 - r_squared: -3.7663
# MSE // MAE // R-squared  [0.20037250220775604, 0.3449424207210541, -3.7663373947143555]
